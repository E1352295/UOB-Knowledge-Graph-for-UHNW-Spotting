# %%
# %pip install playwright pandas tqdm && playwright install

# %%
# !python bloomberg_billionaires_to_csv.py
# Out:
# ✅  Saved 500 rows → bloomberg_billionaires.csv

# %%
# !python sync_billionaires.py \
  --csv bloomberg_billionaires.csv \
  --neo4j-uri neo4j+s://8f6e6423.databases.neo4j.io \
  --neo4j-user neo4j \
  --neo4j-pass TUOx-U2EDDDXXNAteOqarP3aEj7XxMcsoilyEtL7NLI 
#   \
#   --dry-run
# Out:
# 2025-07-23 17:08:00 [INFO] Loaded 500 rows from CSV
# g:\My Drive\NUS MSBA SEM2\UOB\Ranking\Bloomberg\sync_billionaires.py:167: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(write_batch, batch)
# 2025-07-23 17:08:00 [INFO] Created new person: Elon Musk
# 2025-07-23 17:08:00 [INFO] Created new person: Larry Ellison
# 2025-07-23 17:08:00 [INFO] Created new person: Jeff Bezos
# 2025-07-23 17:08:00 [INFO] Created new person: Mark Zuckerberg
# 2025-07-23 17:08:00 [INFO] Created new person: Steve Ballmer
# 2025-07-23 17:08:00 [INFO] Created new person: Larry Page
# 2025-07-23 17:08:00 [INFO] Created new person: Sergey Brin
# 2025-07-23 17:08:00 [INFO] Created new person: Bernard Arnault
# 2025-07-23 17:08:00 [INFO] Created new person: Jensen Huang
# 2025-07-23 17:08:00 [INFO] Created new person: Warren Buffett
# 2025-07-23 17:08:00 [INFO] Created new person: Michael Dell
# 2025-07-23 17:08:00 [INFO] Created new person: Bill Gates
# ...
