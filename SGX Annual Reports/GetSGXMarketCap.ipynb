# %%
# %pip install yfinance lxml
# Out:
# Requirement already satisfied: yfinance in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (0.2.65)
# Collecting lxml
#   Downloading lxml-6.0.0-cp39-cp39-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (2.3.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.6.15)
# Requirement already satisfied: pycparser in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\22601\anaconda3\envs\finer_env\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)
# Downloading lxml-6.0.0-cp39-cp39-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------ --------------------- 1.8/4.0 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf, pandas as pd

tickers = [f"{code}.SI" for code in ["D05","O39","U11","S68"]]  # 自备代码表
rows = []
for t in tickers:
    info = yf.Ticker(t).fast_info  # fast_info 比 .info 更快
    rows.append({"ticker": t, "marketCapUSD": info['marketCap']})

df = pd.DataFrame(rows)           # → marketCap 已是美元值
df.to_csv("G:/My Drive/NUS MSBA SEM2/UOB/SGX Annual Reports/sgx_cap_yf.csv", index=False)
df.to_csv("C:/Users/22601/Downloads/downloads/files/sgx_cap_yf.csv", index=False)

# %%
import pandas as pd, requests, io, datetime as dt

# # 1⃣ 直接下载 StockAnalysis 的“Download”CSV（含 Market Cap, Price, Revenue …）
# csv_url = "https://stockanalysis.com/list/singapore-exchange/?download"
# csv = requests.get(csv_url).content
url = "https://stockanalysis.com/list/singapore-exchange/"
html = requests.get(url).text

# 读取所有 <table> 标签，然后选第一个（通常是我们需要的股价市值表）
dfs = pd.read_html(io.StringIO(html), match="Market Cap")
df = dfs[0]  # 必须用 [0] 拿第一个表，否则 pandas 返回的是 list 而非 DataFrame :contentReference[oaicite:1]{index=1}

# %%
df.size
# Out:
# 1662

# %%
df.head()
# Out:
#    No. Symbol                                      Company Name Market Cap  \
# 0    1   HTCD                          Tencent Holdings Limited    769.42B
# 1    2   HSHD                                 HSBC Holdings plc    279.21B
# 2    3   HXXD                                Xiaomi Corporation    242.16B
# 3    4   HYDD                               BYD Company Limited    182.47B
# 4    5   HPAD  Ping An Insurance (Group) Company of China, Ltd.    173.12B
#
#    Stock Price % Change  Revenue
# 0         8.49    0.12%  126.06B
# 1         3.21    0.31%   77.93B
# 2         4.66    1.08%   74.38B
# 3         2.07        -  152.31B
# 4         4.31    1.89%  175.11B

# %%
df = df[['Symbol', 'Company Name', 'Market Cap']]

# 定义转换函数
def parse_market_cap(val):
    if pd.isna(val):
        return None
    val = val.strip()
    num, suffix = val[:-1], val[-1].upper()
    try:
        num = float(num)
    except ValueError:
        return None
    if suffix == 'B':
        return num * 1e9
    elif suffix == 'M':
        return num * 1e6
    else:
        return num

# 应用转换并生成USD列
df['marketCap'] = df['Market Cap'].apply(parse_market_cap)
SGD2USD = 0.74
df['marketCapUSD'] = df['marketCap'] * SGD2USD

df = df.dropna(subset=['marketCapUSD'])
# Out:
# C:\Users\22601\AppData\Local\Temp\ipykernel_136984\1088437094.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marketCap'] = df['Market Cap'].apply(parse_market_cap)

# %%
df.head()
# Out:
#   Symbol                                      Company Name Market Cap  \
# 0   HTCD                          Tencent Holdings Limited    769.42B
# 1   HSHD                                 HSBC Holdings plc    279.21B
# 2   HXXD                                Xiaomi Corporation    242.16B
# 3   HYDD                               BYD Company Limited    182.47B
# 4   HPAD  Ping An Insurance (Group) Company of China, Ltd.    173.12B
#
#       marketCap  marketCapUSD
# 0  7.694200e+11  5.693708e+11
# 1  2.792100e+11  2.066154e+11
# 2  2.421600e+11  1.791984e+11
# 3  1.824700e+11  1.350278e+11
# 4  1.731200e+11  1.281088e+11

# %%
# 3⃣ 保存到本地供 Cypher LOAD CSV
fname = f"C:/Users/22601/Downloads/downloads/files/sgx_market_cap_{dt.date.today()}.csv"
df[['Symbol','Company Name','marketCapUSD']].to_csv(fname, index=False)
fname = f"G:/My Drive/NUS MSBA SEM2/UOB/SGX Annual Reports/sgx_market_cap_{dt.date.today()}.csv"
df[['Symbol','Company Name','marketCapUSD']].to_csv(fname, index=False)
print("Saved:", fname)
# Out:
# Saved: G:/My Drive/NUS MSBA SEM2/UOB/SGX Annual Reports/sgx_market_cap_2025-07-22.csv

# %%
from neo4j import GraphDatabase
import pandas as pd, datetime as dt

df = pd.read_csv(fname)
URI = "neo4j+s://8f6e6423.databases.neo4j.io"
USER = "neo4j"
PWD = "TUOx-U2EDDDXXNAteOqarP3aEj7XxMcsoilyEtL7NLI"
DRY_RUN = False
driver = GraphDatabase.driver(URI, auth=(USER, PWD))

# ------------------------------------------------------------------
# Load CSV (expect列: Symbol, marketCapUSD)
# ------------------------------------------------------------------
print(f"Loaded {len(df):,} rows from {fname}")
# --- 预处理: 清洗公司名 ---------------------------------------------------
# 去掉首尾空格 / 引号，并统一为大写做匹配

def canon(name: str) -> str:
    return name.strip().strip('"').upper()

df['canonName'] = df['Company Name'].apply(canon)


# -- 检查节点是否存在 -------------------------------------------------------

def node_exists(tx, c_name: str) -> bool:
    return tx.run(
        """
        MATCH (c:Company)
        WHERE toUpper(trim(c.name)) = $n
        RETURN 1 LIMIT 1
        """,
        n=c_name
    ).single() is not None

# -- 更新 marketCap --------------------------------------------------------

def update_market_cap(tx, c_name: str, cap: float, iso_date: str):
    tx.run(
        """
        MATCH (c:Company)
        WHERE toUpper(trim(c.name)) = $n
        SET   c.marketCap     = $cap,
              c.marketCapDate = date($iso)
        """,
        n=c_name, cap=cap, iso=iso_date
    )

# ------------------------------------------------------------------
# Dry‑Run & Commit --------------------------------------------------
# ------------------------------------------------------------------
with driver.session() as sess:
    today_iso = str(dt.date.today())
    todo = []

    # --- Dry‑Run discovery -----------------------------------------
    for _, row in df.iterrows():
        cname = row['canonName']
        cap_usd = float(row['marketCapUSD'])
        if sess.execute_read(node_exists, cname):
            todo.append((cname, cap_usd))

    print(f"Found {len(todo):,} existing companies to update.")

    # --- Preview list ---------------------------------------------
    for n, c in todo[:20]:
        print(f"  {n[:40]:<40} → {c/1e9:,.2f} B USD")
    if len(todo) > 20:
        print("  … (truncated) …")

    # --- Commit ----------------------------------------------------
    if not DRY_RUN:
        for n, c in todo:
            sess.execute_write(update_market_cap, n, c, today_iso)
        print("✅ Update committed.")
    else:
        print("⚠️  DRY_RUN = True → no data written. Set DRY_RUN=False to commit.")

driver.close()
print("Done.")
# Out:
# Loaded 554 rows from G:/My Drive/NUS MSBA SEM2/UOB/SGX Annual Reports/sgx_market_cap_2025-07-22.csv
# Found 134 existing companies to update.
#   PRUDENTIAL PLC                           → 30.13 B USD
#   SINGAPORE TECHNOLOGIES ENGINEERING LTD   → 19.40 B USD
#   SINGAPORE AIRLINES LIMITED               → 16.63 B USD
#   WILMAR INTERNATIONAL LIMITED             → 14.09 B USD
#   CAPITALAND INTEGRATED COMMERCIAL TRUST   → 11.91 B USD
#   CAPITALAND INVESTMENT LIMITED            → 10.15 B USD
#   CAPITALAND ASCENDAS REIT                 → 9.41 B USD
#   NIO INC.                                 → 9.35 B USD
#   MAPLETREE INDUSTRIAL TRUST               → 4.28 B USD
#   OLAM GROUP LIMITED                       → 2.87 B USD
#   SIA ENGINEERING COMPANY LIMITED          → 2.76 B USD
#   VENTURE CORPORATION LIMITED              → 2.66 B USD
#   KEPPEL INFRASTRUCTURE TRUST              → 1.96 B USD
#   FIRST RESOURCES LIMITED                  → 1.79 B USD
#   IFAST CORPORATION LTD.                   → 1.58 B USD
#   CAPITALAND CHINA TRUST                   → 0.99 B USD
#   HONG LEONG ASIA LTD.                     → 0.93 B USD
#   PACIFIC CENTURY REGIONAL DEVELOPMENTS LI → 0.87 B USD
#   FIRST SPONSOR GROUP LIMITED              → 0.85 B USD
#   RIVERSTONE HOLDINGS LIMITED              → 0.77 B USD
#   … (truncated) …
# ✅ Update committed.
# Done.
